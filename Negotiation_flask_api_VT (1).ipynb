# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 12.0 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2024-02-10 15:17:32--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.202.168.65, 18.205.222.128, 54.237.133.81, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.202.168.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.28M  5.51MB/s    in 2.4s
#
# 2024-02-10 15:17:35 (5.51 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# !./ngrok authtoken 2bEMfQZ2SJKNqa6q08X0LpftoGJ_FZq1NpkjRsoqMQAbXvy4
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !pip install flask
# !pip install pyngrok

# %%
# !pip install flask_ngrok

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7 guardrail-ml==0.0.12 tensorboard
# !apt-get -qq install poppler-utils tesseract-ocr
# !pip install -q unstructured["local-inference"]==0.7.4 pillow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 100.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 55.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 51.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 28.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 13.2 MB/s eta 0:00:00
# ...

# %%
# !pip install -U accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.7/279.7 kB 7.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.21.0
#     Uninstalling accelerate-0.21.0:
#       Successfully uninstalled accelerate-0.21.0
# ...

# %%
# !pip install keybert
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 27.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 50.5 MB/s eta 0:00:00
# ...
#   Created wheel for keybert: filename=keybert-0.8.3-py3-none-any.whl size=39124 sha256=957bce8fa6dd8db8a86ef313b86c68978811558f643186914071d926d36208af
#   Stored in directory: /root/.cache/pip/wheels/70/88/07/1a3bc11fd1dd5f89924a02dcbca89a3015e25e8faa31f904dc
# Successfully built keybert
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.31.0
#     Uninstalling transformers-4.31.0:
#       Successfully uninstalled transformers-4.31.0
# ...

# %%
# !pip install flair
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 47.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 37.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 27.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 22.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 93.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Main Frame
# Restart Session to load libraries

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel, get_peft_model
from trl import SFTTrainer
from guardrail.client import (
    run_metrics,
    run_simple_metrics,
    create_dataset)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# Used for multi-gpu
local_rank = -1
per_device_train_batch_size = 4
per_device_eval_batch_size = 4
gradient_accumulation_steps = 1
learning_rate = 2e-4
max_grad_norm = 0.3
weight_decay = 0.001
lora_alpha = 16
lora_dropout = 0.1
lora_r = 64
max_seq_length = None

# The model that you want to train from the Hugging Face hub
model_name = "meta-llama/Llama-2-7b-chat-hf"

# Fine-tuned model name
new_model = "llama-2-7b-nego"

# The instruction dataset to use
dataset_name = "nego_chats"

# Activate 4-bit precision base model loading
use_4bit = True

# Activate nested quantization for 4-bit base models
use_nested_quant = False

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Number of training epochs
num_train_epochs = 2

# Enable fp16 training, (bf16 to True with an A100)
fp16 = False

# Enable bf16 training
bf16 = False

# Use packing dataset creating
packing = False

# Enable gradient checkpointing
gradient_checkpointing = True

# Optimizer to use, original is paged_adamw_32bit
optim = "paged_adamw_32bit"

# Learning rate schedule (constant a bit better than cosine, and has advantage for analysis)
lr_scheduler_type = "cosine"

# Number of optimizer update steps, 10K original, 20 for demo purposes
max_steps = -1

# Fraction of steps to do a warmup for
warmup_ratio = 0.03

# Group sequences into batches with same length (saves memory and speeds up training considerably)
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 10

# Log every X updates steps
logging_steps = 1

# The output directory where the model predictions and checkpoints will be written
output_dir = "./results"

# Load the entire model on the GPU 0
device_map = {"": 0}

# Visualize training
report_to = "tensorboard"

# Tensorboard logs
tb_log_dir = "./results/logs"

# %%
def load_model(model_name):
    # Load tokenizer and model with QLoRA configuration
    compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

    bnb_config = BitsAndBytesConfig(
        load_in_4bit=use_4bit,
        bnb_4bit_quant_type=bnb_4bit_quant_type,
        bnb_4bit_compute_dtype=compute_dtype,
        bnb_4bit_use_double_quant=use_nested_quant,
    )

    if compute_dtype == torch.float16 and use_4bit:
        major, _ = torch.cuda.get_device_capability()
        if major >= 8:
            print("=" * 80)
            print("Your GPU supports bfloat16, you can accelerate training with the argument --bf16")
            print("=" * 80)

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map=device_map,
        quantization_config=bnb_config
    )

    model.config.use_cache = False
    model.config.pretraining_tp = 1

    # Load LoRA configuration
    peft_config = LoraConfig(
        lora_alpha=lora_alpha,
        lora_dropout=lora_dropout,
        r=lora_r,
        bias="none",
        task_type="CAUSAL_LM",
    )

    # Load Tokenizer
    tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.padding_side = "right"

    return model, tokenizer, peft_config

# %%
# !git config --global credential.helper store

# %% [markdown]
# *   Enter the hugging face token to load fine tuned LLM
# *   Enter y after pressing enter
#
#
#
# token => ***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***

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from flair.embeddings import TransformerDocumentEmbeddings
roberta = TransformerDocumentEmbeddings('Felladrin/Llama-160M-Chat-v1')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/650M [00:00<?, ?B/s]

# %%
huggingface_profile = "Murdock007"
full_path = huggingface_profile + "/" + new_model

model, tokenizer,peft_config = load_model(full_path)
# Out:
# config.json:   0%|          | 0.00/630 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00007.bin:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00007.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# pytorch_model-00003-of-00007.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# pytorch_model-00004-of-00007.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# pytorch_model-00005-of-00007.bin:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# pytorch_model-00006-of-00007.bin:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# pytorch_model-00007-of-00007.bin:   0%|          | 0.00/1.66G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# ...

# %%
def text_gen_eval_wrapper(model, tokenizer, prompt, model_id=1, show_metrics=True, temp=0.7, max_length=200):
    """
    A wrapper function for inferencing, evaluating, and logging text generation pipeline.

    Parameters:
        model (str or object): The model name or the initialized text generation model.
        tokenizer (str or object): The tokenizer name or the initialized tokenizer for the model.
        prompt (str): The input prompt text for text generation.
        model_id (int, optional): An identifier for the model. Defaults to 1.
        show_metrics (bool, optional): Whether to calculate and show evaluation metrics.
                                       Defaults to True.
        max_length (int, optional): The maximum length of the generated text sequence.
                                    Defaults to 200.

    Returns:
        generated_text (str): The generated text by the model.
        metrics (dict): Evaluation metrics for the generated text (if show_metrics is True).
    """
    # Suppress Hugging Face pipeline logging
    logging.set_verbosity(logging.CRITICAL)

    # Initialize the pipeline
    pipe = pipeline(task="text-generation",
                    model=model,
                    tokenizer=tokenizer,
                    max_length=max_length,
                    do_sample=True,
                    temperature=temp)

    # Generate text using the pipeline
    pipe = pipeline(task="text-generation",
                    model=model,
                    tokenizer=tokenizer,
                    max_length=200)
    result = pipe(f"<s>[INST] {prompt} [/INST]")
    generated_text = result[0]['generated_text']

    # Find the index of "### Assistant" in the generated text
    index = generated_text.find("[/INST] ")
    if index != -1:
        # Extract the substring after "### Assistant"
        substring_after_assistant = generated_text[index + len("[/INST] "):].strip()
    else:
        # If "### Assistant" is not found, use the entire generated text
        substring_after_assistant = generated_text.strip()

    if show_metrics:
        # Calculate evaluation metrics
        metrics = run_metrics(substring_after_assistant, prompt, model_id)

        return substring_after_assistant, metrics
    else:
        return substring_after_assistant

# %%
# Inference and evaluate outputs/prompts
prompt="I agree the deal can be closed succesfuly now, now negotiate for a better deal on how it can be improved"
result = text_gen_eval_wrapper(model, tokenizer, prompt, show_metrics=False)

# %%
from keybert import KeyBERT

# %%
kw_model = KeyBERT(model=roberta)
res = list(kw_model.extract_keywords(result,keyphrase_ngram_range=(1, 1),use_mmr=True, diversity=1))

# %%
result
# Out:
# "I apologize, but I cannot agree to a better deal as the current offer is the best I can provide. surely, you must know that I am not able to improve the offer further. I am here to help you with the negotiation, but I cannot make any promises that are not within the company's policy. I would suggest you consider the offer as it is, or we can move on to the next topic of discussion. What else would you like to talk about?"

# %%
res
# Out:
# [('know', 0.6357),
#  ('company', 0.5436),
#  ('promises', 0.3704),
#  ('best', 0.3492),
#  ('current', 0.2308)]

# %% [markdown]
# *   Deploying the Model througn NGROK .
# *   Enter the token to generate API link for CURL call
#
#
#
# ngrok authtoken => ***2bEMfQZ2SJKNqa6q08X0LpftoGJ_FZq1NpkjRsoqMQAbXvy4***

# %%
import getpass
import locale
import sys

from pyngrok import ngrok, conf

# Set the locale to the default locale
locale.setlocale(locale.LC_ALL, '')

# Prompt the user to enter the ngrok authtoken
authtoken = getpass.getpass("Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth: ")

# Set the authtoken
conf.get_default().auth_token = authtoken

# Open a TCP ngrok tunnel to the SSH server
tunnel = ngrok.connect(22, "tcp")
ssh_url, port = tunnel.public_url.strip("tcp://").split(":")
tunnel_info = f" * ngrok tunnel available, access with `ssh root@{ssh_url} -p{port}`"

# Encode and print the tunnel information
encoded_tunnel_info = tunnel_info.encode(sys.stdout.encoding, errors='replace')
print(encoded_tunnel_info.decode())
# Out:
# Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth: ··········
# WARNING:pyngrok.process.ngrok:t=2024-02-10T15:28:53+0000 lvl=warn msg="ngrok config file found at both XDG and legacy locations, using XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# Exception in thread Thread-13 (_monitor_process):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pyngrok/process.py", line 140, in _monitor_process
#     self._log_line(self.proc.stdout.readline())
#   File "/usr/lib/python3.10/encodings/ascii.py", line 26, in decode
#     return codecs.ascii_decode(input, self.errors)[0]
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc2 in position 183: ordinal not in range(128)
# ...

# %% [markdown]
# The NGROK will make a new tunnel upon which the colab noteboook is hoted . The Notebook will run on the tunnel made and the routes (response) can be viewed by calling the endpoints on POSTMAN.

# %%
import getpass

from pyngrok import ngrok, conf

print("Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth")
conf.get_default().auth_token = getpass.getpass()

# Open a TCP ngrok tunnel to the SSH server
connection_string = ngrok.connect("22", "tcp").public_url

ssh_url, port = connection_string.strip("tcp://").split(":")
print(f" * ngrok tunnel available, access with `ssh root@{ssh_url} -p{port}`")
# Out:
# Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth
# ··········
#  * ngrok tunnel available, access with `ssh root@4.tcp.ngrok.io -p15706`

# %% [markdown]
# # Pipeline

# %% [markdown]
# ### An effort to integrate all the API into single frame to make it into one stop API for negotiation adn deals initiation in ONDC Framework

# %% [markdown]
# The code is commented due to lack of access to API

# %%
# import http.client

# def pipeline(website,method,headers,payload):
#   conn = http.client.HTTPSConnection(website)

#   # headers = {
#   #   'X-Gateway-Authorization': "REPLACE_KEY_VALUE",
#   #   'content-type': "application/json"
#   #   }

#   if(method=='search'):
#     conn.request("POST", "/search", payload, headers)
#   if(method=='select'):
#     conn.request("POST","/select",payload,headers)
#   if(method=='init'):
#     conn.request("POST","/init",payload,headers)
#   res = conn.getresponse()
#   data = res.read()
#   return data

# %%
import spacy
# Load the spaCy model
nlp = spacy.load("en_core_web_md")

# %% [markdown]
# ***/generate_text is the main API for similarity score and embedded intelligence with langchain to make it into stateful API***

# %%
# calling the function in the return part
# Original code
import os
import threading
from flask import Flask, jsonify, request, redirect
from pyngrok import ngrok

app = Flask(__name__)
port = 5000

# Function for text generation
# @app.route("/text_generation_function", methods=['POST'])
# def text_gen_eval_wrapper(prompt):
#     # Replace this with the actual implementation of text generation using your model and tokenizer
#     return "Generated text based on prompt: " + prompt

# Open a ngrok tunnel to the HTTP server
public_url = ngrok.connect(port).public_url
print(f" * ngrok tunnel \"{public_url}\" -> \"http://127.0.0.1:{port}\"")

# Define Flask routes
@app.route("/")
def index():
  # return text_generation_function("hello")
    return {"message": "Welcome to the NGROK API!"}

@app.route("/methods")
def methodolgy():
  pass

# Endpoint for text generation
@app.route("/generate_text", methods=['POST'])
def generate_text():
    if request.method == 'POST':
      try:
        data = request.json
        prompt = data['data']
        # Call the text generation function with the provided prompt
        costs = prompt['message']['quote']['price']
        prompt = f"The following is the price of the {costs} article as a negotiation engine negotiate with me for a better deal, which can be reached on a better conclusion"

        generated_text = text_gen_eval_wrapper(model, tokenizer, prompt, show_metrics=False)
        # kw_model = KeyBERT(model=roberta)
        # res = list(kw_model.extract_keywords(result,keyphrase_ngram_range=(1, 1),use_mmr=True, diversity=1))
        # res[0][0]
        doc1 = "Similarity from buffer memory of langchain"
        doc1 = nlp(doc1)
        doc2= nlp(generated_text)
        semantic_similarity = doc1.similarity(doc2)
        return jsonify({"generated_text": generated_text,"similarity score":semantic_similarity,"message": {"ack": { "status": "ACK"}}})
      except:
         return jsonify({"error": {
        "type": "CONTEXT-ERROR",
        "code": "code",
        "path": "path",
        "message": "message"
      }})
    else:
       return "Method Not Allowed"

# Start the Flask server in a new thread
threading.Thread(target=app.run, kwargs={"host": "0.0.0.0", "port": port, "use_reloader": False}).start()
# Out:
#  * ngrok tunnel "https://86d1-34-124-249-205.ngrok-free.app" -> "http://127.0.0.1:5000"
